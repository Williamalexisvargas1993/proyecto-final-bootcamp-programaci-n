# %% [markdown]
# **los pasos a seguir en estos estadisticos son;
#
# 1.Hacer la lectura de datos de excel a python
#
# 2. Crear de la base de datos una subbase, correspndiente a la zona de  Sur America (produccion y consumo de energía)
#
# 3. Con esta nueva base de datos vamos a crear los estadisticos correspondientes;
#
# A. un grafico de lineas para el consumo de las principales energias renovables y un grafico de lineas para la produccion de las principales energías renovables
#
# B. un grafico de torta desplazada para el año de 1965 (inicio de los registros), y un grafico de torta desplazada para el año 2021(final de los registros) con su correspondiente interpretación
#
# c. un grafico de áreas apiladas para el consumo de las principales fuentes de energía renovable
#
# d. un diagrama de la correlación lineal que pueda existir entre la principal fuente de energía y su paso del tiempo**

# %%
import matplotlib.pyplot as plt
import pandas as pd

datos1 = pd.read_csv("consumo_energia_ren.csv")
datos2 = pd.read_csv("produccion_energia_ren.csv")


datos1
# Out:
#       Entity      Code  Year  Geo Biomass Other - TWh  Solar Generation - TWh  \
# 0     Africa       NaN  1965                      NaN                     NaN
# 1     Africa       NaN  1966                      NaN                     NaN
# 2     Africa       NaN  1967                      NaN                     NaN
# 3     Africa       NaN  1968                      NaN                     NaN
# 4     Africa       NaN  1969                      NaN                     NaN
# ...      ...       ...   ...                      ...                     ...
# 5605   World  OWID_WRL  2017                596.42050               445.46628
# 5606   World  OWID_WRL  2018                643.03204               576.23090
# 5607   World  OWID_WRL  2019                674.74536               703.94977
# 5608   World  OWID_WRL  2020                703.91644               846.22940
# 5609   World  OWID_WRL  2021                762.78265              1032.50120
#
#       Wind Generation - TWh  Hydro Generation - TWh
# 0                    0.0000               13.905635
# 1                    0.0000               15.510005
# 2                    0.0000               16.190636
# 3                    0.0000               18.938341
# 4                    0.0000               22.100891
# ...                     ...                     ...
# 5605              1140.3931             4069.982700
# 5606              1269.9792             4183.166500
# 5607              1420.5441             4231.377000
# 5608              1596.4282             4345.990000
# 5609              1861.9398             4273.827600
#
# [5610 rows x 7 columns]

# %% [markdown]
# Solo queremos de la base de datos. la información correspondiente a Sur America

# %%
import matplotlib.pyplot as plt
import pandas as pd

datos1 = pd.read_csv("consumo_energia_ren.csv")


#Seleccion de datos unicamente de la zona europa
Suramerica1 = datos1[datos1['Entity'] == 'South America']

#Estos datos pertenecen al consumo de energía de la zona llamada Europa 

años = Suramerica1['Year']
energia1 =  Suramerica1['Geo Biomass Other - TWh']
energia2 =  Suramerica1['Hydro Generation - TWh']
energia3 =  Suramerica1['Solar Generation - TWh']
energia4 =  Suramerica1['Wind Generation - TWh']


#vamos a hacer el gráfico de lineas
plt.figure(figsize=(15,6))
plt.plot(años,energia1, label='Biomasa')
plt.plot(años,energia2, label='Hidroelectrica')
plt.plot(años,energia3, label='Solar')
plt.plot(años,energia4, label='Eolica')


#Añadir etiquetas y titulos
plt.title('Consumo  Energia Limpia Suramerica',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel( 'Consumo Energetico(TWH)',fontsize=14)

#Mostrar leyenda
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.savefig('Consumo_Sura')
plt.show()

###########################################################################

datos2 = pd.read_csv("produccion_energia_ren.csv")


#Seleccion de datos unicamente de la zona europa
Suramerica2 = datos2[datos2['Entity'] == 'South America']

#Estos datos pertenecen a la producción  de Energía de la zona llamada Europa 

años = Suramerica2['Year']
energia5 = Suramerica2['Electricity from hydro (TWh)']
energia6 = Suramerica2['Electricity from solar (TWh)']
energia7 = Suramerica2['Electricity from wind (TWh)']
energia8 = Suramerica2['Other renewables including bioenergy (TWh)']


#vamos a hacer el gráfico de lineas
plt.figure(figsize=(15,6))
plt.plot(años,energia5, label='Hidroelectrica')
plt.plot(años,energia6, label='Solar')
plt.plot(años,energia7, label='Eolica')
plt.plot(años,energia8, label='Otras fuentes')


#Añadir etiquetas y titulos
plt.title('Producción Energia Limpia Suramerica',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel( 'Producción Energetica(TWH)',fontsize=14)

#Mostrar leyenda
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.savefig('Produccion_Sura')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

#Este es el consumo de energía renovable en Europa 1965
Suramerica1965 = Suramerica1[Suramerica1['Year'] == 1965]


estSuramerica1965 = pd.DataFrame(Suramerica1965)

estSuramerica1965

#Despues de calcular los estadisticos y tener los datos. Hacemos un diaggrama de torta desplazado

tipo_es_1965 = ['Biomasa','Solar','Eolica','Hidroelectrica']
consumos_es_1965 =[0, 0.0, 0.0,	39.581554]

fig,ax = plt.subplots()
explode = (0.2,0,0,0)

ax.pie(consumos_es_1965,labels=tipo_es_1965,autopct='%1.1f%%', explode=explode, startangle=180, shadow=True)
ax.axis('equal')

plt.title('Consumo Energía 1965 Suramerica (TWh)',fontsize=14)
plt.savefig('torta_sura_1965')
plt.show()



#Ahora vamos a crear el diagrama de torta desplazada para Africa en el año 2021

#Este es el consumo de energía renovable en Africa en 2021
Suramerica2021 = Suramerica1[Suramerica1['Year'] == 2021]



estSuramerica2021 = pd.DataFrame(Suramerica2021)

estSuramerica2021

#Despues de calcular los estadisticos y tener los datos. Hacemos un diaggrama de torta desplazado

tipo_es_2021 = ['Biomasa','Solar','Eolica','Hidroelectrica']
consumos_es_2021 =[72.658905, 31.772686, 101.82825, 628.21277]

fig,ax = plt.subplots()
explode = (0,0,0,0.2)

ax.pie(consumos_es_2021,labels=tipo_es_2021,autopct='%1.1f%%', explode=explode, startangle=90, shadow=True)
ax.axis('equal')

plt.title('Consumo Energía Suramerica 2021 (TWh)',fontsize=14)
plt.savefig('torta_2021_Sura')
plt.show()

# %%
Suramerica1965 = Suramerica1[Suramerica1['Year'] == 1965]


estSuramerica1965 = pd.DataFrame(Suramerica1965)

estSuramerica1965
# Out:
#              Entity Code  Year  Geo Biomass Other - TWh  \
# 4396  South America  NaN  1965                      0.0
#
#       Solar Generation - TWh  Wind Generation - TWh  Hydro Generation - TWh
# 4396                     NaN                    NaN               39.581554

# %%
Suramerica2021 = Suramerica1[Suramerica1['Year'] == 2021]



estSuramerica2021 = pd.DataFrame(Suramerica2021)

estSuramerica2021
# Out:
#              Entity Code  Year  Geo Biomass Other - TWh  \
# 4452  South America  NaN  2021                72.658905
#
#       Solar Generation - TWh  Wind Generation - TWh  Hydro Generation - TWh
# 4452               31.772686              101.82825               628.21277

# %% [markdown]
# Procedemos ahora hacer el diagrama de áreas apiladas

# %%
años = Suramerica1['Year']
energia1 = Suramerica1['Geo Biomass Other - TWh']
energia2 = Suramerica1['Hydro Generation - TWh']
energia3 = Suramerica1['Solar Generation - TWh']
energia4 = Suramerica1['Wind Generation - TWh']

#Vamos a crear el diagrama de barra apiladas
plt.figure(figsize=(15,6))
plt.stackplot(años,energia1,energia2,energia3,energia4,labels=['Biomasa','Hidroelectrica','Solar','Eolica'],
              colors=["#4106d8","#7c0a90","#06dc26",'#f4f80b'])


#Añadimos titulos y etiquetas 

plt.title('Consumos Energía Limpia Suramerica',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel('Consumo (TWh)',fontsize=14)

#leyenda
plt.legend()

#Mostrar gráfica
plt.grid(True)
plt.tight_layout()
plt.savefig('Areas_Sura')
plt.show()

# %% [markdown]
# vamos a ver ahora si encontamos una relación entre dos variables por medio de un grafico de disperción

# %%
#importamos las librerias con las que vamos a trabajar
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#hacemos la lectura de los datos de las dos bases de datos que dejamos para trabajar. 

#empezamos a trabajar con los datos de las listas
# Estas son las dos variables que vamos a a estudair a ver si encotramos alguna relación

#Produccion de energia limpia en Europa
datos2 = pd.read_csv("produccion_energia_ren.csv")

Suramerica2= datos2[datos2['Entity']=='South America']

años = Suramerica2['Year']
energia5 = Suramerica2['Electricity from hydro (TWh)']


# Calculamos el coeficioente de correlación

correlation = np.corrcoef(años,energia5)[0, 1]

print(f"Correlation coefficient: {correlation}")

# Plotting the data
plt.figure(figsize=(15,6))
plt.scatter(años,energia5)
plt.title('relación de Produccion de Energía Hidroelectrica a través de los años',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel('Consumo (TWh)',fontsize=14)
plt.savefig('correlacion_Sura1')
plt.show()
# Out:
# Correlation coefficient: 0.9833354628839833

# %% [markdown]
# ## **Correlación: Nos dice tanto la dirección como la fuerza de la relación lineal. Un valor cercano a 1 o -1 indica una relación lineal fuerte, mientras que un valor cercano a 0 indica una relación débil o nula**

# %% [markdown]
# ya tenemos las bases de datos con las que vamos a trabajar nuestros estadisticos. después de la depuración por el tiempo de entrega y debido a que nuestro equipo se redujo drasticamente. optamos por quedarnos solamente con las hojas del excel #2 y #3. depués de inspeccion de datos, concluimos son las más completas
#
# como tenemos una base de datos tan grande (5602) datos y mucha variedad en la recopilación vamos a crear sub bases de datos con la información de interes para posteriormente calcular los estadisticos y analizar los datos
#
# mi primer sub grupo de datos se trabajaran con los siguientes areas
#
# 1. Africa
# 2. Asia
# 3.Europa
# 4.Oceania
# 5.America del norte (la cual por motivos de espacio llamaremos AmericaN)
#
#
# mi segundo subgrupo para el Area de estudio sera;
#
# 1. sur America
# 2. Colombia

# %%
import matplotlib.pyplot as plt
import pandas as pd

#hacemos la lectura de los datos de las dos bases de datos que dejamos para trabajar. 
datos1 = pd.read_csv("consumo_energia_ren.csv") 
datos2 = pd.read_csv("produccion_energia_ren.csv")


print(datos1)
# Out:
#       Entity      Code  Year  Geo Biomass Other - TWh  Solar Generation - TWh  \
# 0     Africa       NaN  1965                      NaN                     NaN
# 1     Africa       NaN  1966                      NaN                     NaN
# 2     Africa       NaN  1967                      NaN                     NaN
# 3     Africa       NaN  1968                      NaN                     NaN
# 4     Africa       NaN  1969                      NaN                     NaN
# ...      ...       ...   ...                      ...                     ...
# 5605   World  OWID_WRL  2017                596.42050               445.46628
# 5606   World  OWID_WRL  2018                643.03204               576.23090
# 5607   World  OWID_WRL  2019                674.74536               703.94977
# 5608   World  OWID_WRL  2020                703.91644               846.22940
# 5609   World  OWID_WRL  2021                762.78265              1032.50120
#
#       Wind Generation - TWh  Hydro Generation - TWh
# 0                    0.0000               13.905635
# 1                    0.0000               15.510005
# 2                    0.0000               16.190636
# 3                    0.0000               18.938341
# 4                    0.0000               22.100891
# ...                     ...                     ...
# 5605              1140.3931             4069.982700
# 5606              1269.9792             4183.166500
# 5607              1420.5441             4231.377000
# 5608              1596.4282             4345.990000
# 5609              1861.9398             4273.827600
#
# [5610 rows x 7 columns]

# %%
# empezamos a depurar datos, dejando solo los de interes para nuestra labor estadistica


#importamos las librerias con las que vamos a trabajar
import matplotlib.pyplot as plt
import pandas as pd

#hacemos la lectura de los datos de las dos bases de datos que dejamos para trabajar. 
datos1 = pd.read_csv("consumo_energia_ren.csv") 


#Ahora vamos a ir depurando datos que nos hacen ruido en nuestro trabajo
Africa1= datos1[datos1['Entity']=='Africa']


#empezamos a trabajar con los datos de las listas

años = Africa1['Year']
energia1 = Africa1['Geo Biomass Other - TWh']
energia2 = Africa1['Hydro Generation - TWh']
energia3 = Africa1['Solar Generation - TWh']
energia4 = Africa1['Wind Generation - TWh']


#vamos a hacer el gráfico de lineas
plt.figure(figsize=(15,6))
plt.plot(años,energia1, label='Biomasa')
plt.plot(años,energia2, label='Hidroelectrica')
plt.plot(años,energia3, label='Solar')
plt.plot(años,energia4, label='Eolica')



#Añadir etiquetas y titulos

plt.title('Consumo  Energia Limpia Africa',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel( 'Consumo Energetico(TWH)',fontsize=14)

#Mostrar leyenda
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.savefig('consumo_Africa.png')
plt.show()

#Produccion de energia limpia en Africa
datos2 = pd.read_csv("produccion_energia_ren.csv")

Africa2= datos2[datos2['Entity']=='Africa']

años = Africa2['Year']
energia5 = Africa2['Electricity from hydro (TWh)']
energia6 = Africa2['Electricity from solar (TWh)']
energia7 = Africa2['Electricity from wind (TWh)']
energia8 = Africa2['Other renewables including bioenergy (TWh)']

plt.figure(figsize=(15,6))
plt.plot(años,energia5, label='Electricidad de Hidroelectrica')
plt.plot(años,energia6, label='Electricidad de solar')
plt.plot(años,energia7, label='Electricidad de eolica')
plt.plot(años,energia8, label='Electricida de bioenergía')

#Añadir etiquetas y titulos

plt.title('Producción  Energia Limpia Africa',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel( 'Valor Energetico(TWH)', fontsize=14)

#Mostrar leyenda
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.savefig('produccion_Africa.png')
plt.show()

# %% [markdown]
# ya tenemos unos estadisticos principales para Africa. Que es un grafico de lineas por cada tipo de energía. Hay dos gráficas;
# 1. Una para la produccion de energías limpias desde 1965 hasta 2021
# 2. Una para el consumo de energias limpias desde 1965 hasta 20221
# 3. Vamos a crear una tabla de frecuencias para el tipo de energias en l965 y otro para el 2021

# %%
import matplotlib.pyplot as plt
import pandas as pd

#Este es el consumo de energía renovable en Africa en 1965
Africa1965 = Africa1[Africa1['Year'] == 1965]

#print(Africa1965) 

estAfrica1965 = pd.DataFrame(Africa1965)

estAfrica1965

#Despues de calcular los estadisticos y tener los datos. Hacemos un diaggrama de torta desplazado

tipo_ea_1965 = ['Biomasa','Solar','Eolica','Hidroelectrica']
consumos_ea_1965 =[0,0,0,13.905635]

fig,ax = plt.subplots()
explode = (0.1,0,0,0)

ax.pie(consumos_ea_1965,labels=tipo_ea_1965,autopct='%1.1f%%', explode=explode, startangle=90, shadow=True)
ax.axis('equal')

plt.title('Consumo Energía 1965 Africa (TWh)', fontsize=14)
plt.savefig('torta_Africa_1965.png')
plt.show()



#Ahora vamos a crear el diagrama de torta desplazada para Africa en el año 2021

#Este es el consumo de energía renovable en Africa en 2021
Africa2021 = Africa1[Africa1['Year'] == 2021]

#print(Africa2021)

estAfrica2021 = pd.DataFrame(Africa2021)

estAfrica2021

#Despues de calcular los estadisticos y tener los datos. Hacemos un diaggrama de torta desplazado

tipo_ea_2021 = ['Biomasa','Solar','Eolica','Hidroelectrica']
consumos_ea_2021 =[8.026317,16.515236,24.41597,153.4187]

fig,ax = plt.subplots()
explode = (0,0,0,0.2)

ax.pie(consumos_ea_2021,labels=tipo_ea_2021,autopct='%1.1f%%', explode=explode, startangle=90, shadow=True)
ax.axis('equal')

plt.title('Consumo Energía 2021 Africa (TWh)', fontsize=14)
plt.savefig('torta_Africa_2021')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

#Este es el consumo de energía renovable en Africa en 1965
Africa1965 = Africa1[Africa1['Year'] == 1965]

estAfrica1965 = pd.DataFrame(Africa1965)

estAfrica1965
# Out:
#    Entity Code  Year  Geo Biomass Other - TWh  Solar Generation - TWh  \
# 0  Africa  NaN  1965                      NaN                     NaN
#
#    Wind Generation - TWh  Hydro Generation - TWh
# 0                    0.0               13.905635

# %%
#Este es el consumo de energía renovable en Africa en 2021
Africa2021 = Africa1[Africa1['Year'] == 2021]


estAfrica2021 = pd.DataFrame(Africa2021)

estAfrica2021
# Out:
#     Entity Code  Year  Geo Biomass Other - TWh  Solar Generation - TWh  \
# 56  Africa  NaN  2021                 8.026317               16.515236
#
#     Wind Generation - TWh  Hydro Generation - TWh
# 56               24.41597                153.4187

# %% [markdown]
# vamos un gráfico de áreas apiladas a través de una linea de tiempo con cada tipo de energía

# %%
# Los datos con los que vamos a trabajar

años = Africa1['Year']
energia1 = Africa1['Geo Biomass Other - TWh']
energia2 = Africa1['Hydro Generation - TWh']
energia3 = Africa1['Solar Generation - TWh']
energia4 = Africa1['Wind Generation - TWh']

#Vamos a crear el diagrama de barra apiladas
plt.figure(figsize=(15,6))
plt.stackplot(años,energia1,energia2,energia3,energia4,labels=['Biomasa','Hidroelectrica','Solar','Eolica'],
              colors=['#1f77b4','#ff7f0e','#2ca02c','#f4f80b'])


#Añadimos titulos y etiquetas 

plt.title('Consumos Energía Limpia Africa', fontsize=14)
plt.xlabel('Años', fontsize=14)
plt.ylabel('Consumo (TWh)',fontsize=14)

#leyenda
plt.legend()

#Mostrar gráfica
plt.grid(True)
plt.tight_layout()
plt.savefig('areas_Africa.png')
plt.show()

# %% [markdown]
# vamos a ver ahora si encontamos una relación entre dos variables por medio de un grafico de disperción

# %%
# empezamos a depurar datos, dejando solo los de interes para nuestra labor estadistica



#importamos las librerias con las que vamos a trabajar
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#hacemos la lectura de los datos de las dos bases de datos que dejamos para trabajar. 

#empezamos a trabajar con los datos de las listas
# Estas son las dos variables que vamos a a estudair a ver si encotramos alguna relación

#Produccion de energia limpia en Africa
datos2 = pd.read_csv("produccion_energia_ren.csv")

Africa2= datos2[datos2['Entity']=='Africa']

años = Africa2['Year']
energia5 = Africa2['Electricity from hydro (TWh)']


# Calculating the correlation coefficient

correlation = np.corrcoef(años,energia5)[0, 1]

print(f"Correlation coefficient: {correlation}")

# Plotting the data
plt.figure(figsize=(15,6))
plt.scatter(años,energia5)
plt.title('Relación de Produccion de Energía Hidroelectrica a través de los años',fontsize=14)
plt.xlabel('Años',fontsize=14)
plt.ylabel('Consumo (TWh)',fontsize=14)
plt.savefig('correlaccion_Africa1.png')
plt.show()
# Out:
# Correlation coefficient: 0.974898930241001

# %% [markdown]
# ## **Correlación: Nos dice tanto la dirección como la fuerza de la relación lineal. Un valor cercano a 1 o -1 indica una relación lineal fuerte, mientras que un valor cercano a 0 indica una relación débil o nula**
